# %%
import pandas as pd
import requests
from urllib.parse import urljoin

# %%
BASE_URL = "https://fantasy.premierleague.com/api/entry"

# %%
manager_id = "5252797"

# %%
MANAGER_URL = urljoin(f"{BASE_URL}/", manager_id)

# %%
response = requests.get(MANAGER_URL)

# %%
data = response.json()

# %%
data
# Out:
# {'id': 5252797,
#  'joined_time': '2025-08-10T14:25:50.521356Z',
#  'started_event': 1,
#  'favourite_team': None,
#  'player_first_name': 'Arnav',
#  'player_last_name': 'Bhatia',
#  'player_region_id': 100,
#  'player_region_name': 'India',
#  'player_region_iso_code_short': 'IN',
#  'player_region_iso_code_long': 'IND',
#  'years_active': 9,
#  'summary_overall_points': 117,
#  'summary_overall_rank': 375361,
#  'summary_event_points': 39,
#  'summary_event_rank': 2932372,
#  'current_event': 2,
#  'leagues': {'classic': [{'id': 120,
#     'name': 'India',
#     'short_name': 'region-100',
#     'created': '2025-07-20T23:14:30.449476Z',
#     'closed': False,
#     'rank': None,
#     'max_entries': None,
#     'league_type': 's',
#     'scoring': 'c',
#     'admin_entry': None,
#     'start_event': 1,
#     'entry_can_leave': False,
#     'entry_can_admin': False,
#     'entry_can_invite': False,
#     'has_cup': True,
#     'cup_league': None,
#     'cup_qualified': None,
#     'rank_count': 186287,
#     'entry_percentile_rank': 5,
#     'active_phases': [{'phase': 1,
#       'rank': 3131,
#       'last_rank': 4314,
#       'rank_sort': 3246,
#       'total': 96,
#       'league_id': 120,
#       'rank_count': 186287,
#       'entry_percentile_rank': 5},
#      {'phase': 2,
#       'rank': 3131,
#       'last_rank': 4314,
#       'rank_sort': 3246,
#       'total': 96,
#       'league_id': 120,
#       'rank_count': 186287,
#       'entry_percentile_rank': 5}],
#     'entry_rank': 3131,
#     'entry_last_rank': 4314},
#    {'id': 276,
#     'name': 'Gameweek 1',
#     'short_name': 'event-1',
#     'created': '2025-07-20T23:14:33.264422Z',
#     'closed': False,
#     'rank': None,
#     'max_entries': None,
#     'league_type': 's',
#     'scoring': 'c',
#     'admin_entry': None,
#     'start_event': 1,
#     'entry_can_leave': False,
#     'entry_can_admin': False,
#     'entry_can_invite': False,
#     'has_cup': False,
#     'cup_league': None,
#     'cup_qualified': None,
#     'rank_count': 9465687,
#     'entry_percentile_rank': 5,
#     'active_phases': [{'phase': 1,
#       'rank': 221120,
#       'last_rank': 288561,
#       'rank_sort': 229897,
#       'total': 96,
#       'league_id': 276,
#       'rank_count': 9465687,
#       'entry_percentile_rank': 5},
#      {'phase': 2,
#       'rank': 221120,
#       'last_rank': 288561,
#       'rank_sort': 229897,
#       'total': 96,
#       'league_id': 276,
#       'rank_count': 9465643,
#       'entry_percentile_rank': 5}],
#     'entry_rank': 221120,
#     'entry_last_rank': 288561},
#    {'id': 314,
#     'name': 'Overall',
#     'short_name': 'overall',
#     'created': '2025-07-20T23:14:33.933835Z',
#     'closed': False,
#     'rank': None,
#     'max_entries': None,
#     'league_type': 's',
#     'scoring': 'c',
#     'admin_entry': None,
#     'start_event': 1,
#     'entry_can_leave': False,
#     'entry_can_admin': False,
#     'entry_can_invite': False,
#     'has_cup': True,
#     'cup_league': None,
#     'cup_qualified': None,
#     'rank_count': 10755611,
#     'entry_percentile_rank': 5,
#     'active_phases': [{'phase': 1,
#       'rank': 375361,
#       'last_rank': 288561,
#       'rank_sort': 386558,
#       'total': 117,
#       'league_id': 314,
#       'rank_count': 10755611,
#       'entry_percentile_rank': 5},
#      {'phase': 2,
#       'rank': 221120,
#       'last_rank': 288561,
#       'rank_sort': 229897,
#       'total': 96,
#       'league_id': 314,
#       'rank_count': 10757708,
#       'entry_percentile_rank': 5}],
#     'entry_rank': 375361,
#     'entry_last_rank': 288561},
#    {'id': 328,
#     'name': 'Jio Star League',
#     'short_name': 'brd-starsports',
#     'created': '2025-07-20T23:14:34.189504Z',
#     'closed': False,
#     'rank': None,
#     'max_entries': None,
#     'league_type': 's',
#     'scoring': 'c',
#     'admin_entry': None,
#     'start_event': 1,
#     'entry_can_leave': False,
#     'entry_can_admin': False,
#     'entry_can_invite': False,
#     'has_cup': True,
#     'cup_league': None,
#     'cup_qualified': None,
#     'rank_count': 47552,
#     'entry_percentile_rank': 5,
#     'active_phases': [{'phase': 1,
#       'rank': 1018,
#       'last_rank': 1090,
#       'rank_sort': 1053,
#       'total': 117,
#       'league_id': 328,
#       'rank_count': 47552,
#       'entry_percentile_rank': 5},
#      {'phase': 2,
#       'rank': 795,
#       'last_rank': 1090,
#       'rank_sort': 824,
#       'total': 96,
#       'league_id': 328,
#       'rank_count': 47566,
#       'entry_percentile_rank': 5}],
#     'entry_rank': 1018,
#     'entry_last_rank': 1090},
#    {'id': 333,
#     'name': 'Second Chance',
#     'short_name': 'sc',
#     'created': '2025-07-20T23:14:34.276586Z',
#     'closed': False,
#     'rank': None,
#     'max_entries': None,
#     'league_type': 's',
#     'scoring': 'c',
#     'admin_entry': None,
#     'start_event': 21,
#     'entry_can_leave': False,
#     'entry_can_admin': False,
#     'entry_can_invite': False,
#     'has_cup': False,
#     'cup_league': None,
#     'cup_qualified': None,
#     'rank_count': None,
#     'entry_percentile_rank': None,
#     'active_phases': [{'phase': 1,
#       'rank': 0,
#       'last_rank': 0,
#       'rank_sort': 0,
#       'total': 0,
#       'league_id': 333,
#       'rank_count': None,
#       'entry_percentile_rank': None},
#      {'phase': 2,
#       'rank': 0,
#       'last_rank': 0,
#       'rank_sort': 0,
#       'total': 0,
#       'league_id': 333,
#       'rank_count': None,
#       'entry_percentile_rank': None}],
#     'entry_rank': 0,
#     'entry_last_rank': 0},
#    {'id': 6037,
#     'name': 'Sortitoutsi',
#     'short_name': None,
#     'created': '2025-07-21T11:46:32.507445Z',
#     'closed': False,
#     'rank': None,
#     'max_entries': None,
#     'league_type': 'x',
#     'scoring': 'c',
#     'admin_entry': 34121,
#     'start_event': 1,
#     'entry_can_leave': True,
#     'entry_can_admin': False,
#     'entry_can_invite': False,
#     'has_cup': True,
#     'cup_league': None,
#     'cup_qualified': None,
#     'rank_count': 3497,
#     'entry_percentile_rank': 5,
#     'active_phases': [{'phase': 1,
#       'rank': 98,
#       'last_rank': 92,
#       'rank_sort': 101,
#       'total': 117,
#       'league_id': 6037,
#       'rank_count': 3497,
#       'entry_percentile_rank': 5},
#      {'phase': 2,
#       'rank': 69,
#       'last_rank': 92,
#       'rank_sort': 73,
#       'total': 96,
#       'league_id': 6037,
#       'rank_count': 3498,
#       'entry_percentile_rank': 5}],
#     'entry_rank': 98,
#     'entry_last_rank': 92},
#    {'id': 24857,
#     'name': '@OfficialFPL on X',
#     'short_name': None,
#     'created': '2025-07-21T12:30:35.770965Z',
#     'closed': False,
#     'rank': None,
#     'max_entries': None,
#     'league_type': 'x',
#     'scoring': 'c',
#     'admin_entry': 123,
#     'start_event': 1,
#     'entry_can_leave': True,
#     'entry_can_admin': False,
#     'entry_can_invite': False,
#     'has_cup': True,
#     'cup_league': None,
#     'cup_qualified': None,
#     'rank_count': 54102,
#     'entry_percentile_rank': 5,
#     'active_phases': [{'phase': 1,
#       'rank': 1855,
#       'last_rank': 1761,
#       'rank_sort': 1933,
#       'total': 117,
#       'league_id': 24857,
#       'rank_count': 54102,
#       'entry_percentile_rank': 5},
#      {'phase': 2,
#       'rank': 1223,
#       'last_rank': 1761,
#       'rank_sort': 1311,
#       'total': 96,
#       'league_id': 24857,
#       'rank_count': 54106,
#       'entry_percentile_rank': 5}],
#     'entry_rank': 1855,
#     'entry_last_rank': 1761},
#    {'id': 24868,
#     'name': 'FPL Pod',
#     'short_name': None,
#     'created': '2025-07-21T12:30:37.484102Z',
#     'closed': False,
#     'rank': None,
#     'max_entries': None,
#     'league_type': 'x',
#     'scoring': 'c',
#     'admin_entry': 123,
#     'start_event': 1,
#     'entry_can_leave': True,
#     'entry_can_admin': False,
#     'entry_can_invite': False,
#     'has_cup': True,
#     'cup_league': None,
#     'cup_qualified': None,
#     'rank_count': 78617,
#     'entry_percentile_rank': 5,
#     'active_phases': [{'phase': 1,
#       'rank': 2629,
#       'last_rank': 2793,
#       'rank_sort': 2750,
#       'total': 117,
#       'league_id': 24868,
#       'rank_count': 78617,
#       'entry_percentile_rank': 5},
#      {'phase': 2,
#       'rank': 1903,
#       'last_rank': 2793,
#       'rank_sort': 2036,
#       'total': 96,
#       'league_id': 24868,
#       'rank_count': 78588,
#       'entry_percentile_rank': 5}],
#     'entry_rank': 2629,
#     'entry_last_rank': 2793},
#    {'id': 42482,
#     'name': 'MATCH Magazine',
#     'short_name': None,
#     'created': '2025-07-21T13:15:12.276516Z',
#     'closed': False,
#     'rank': None,
#     'max_entries': None,
#     'league_type': 'x',
#     'scoring': 'c',
#     'admin_entry': 232760,
#     'start_event': 1,
#     'entry_can_leave': True,
#     'entry_can_admin': False,
#     'entry_can_invite': False,
#     'has_cup': True,
#     'cup_league': None,
#     'cup_qualified': None,
#     'rank_count': 2355,
#     'entry_percentile_rank': 5,
#     'active_phases': [{'phase': 1,
#       'rank': 65,
#       'last_rank': 56,
#       'rank_sort': 68,
#       'total': 117,
#       'league_id': 42482,
#       'rank_count': 2355,
#       'entry_percentile_rank': 5},
#      {'phase': 2,
#       'rank': 39,
#       'last_rank': 56,
#       'rank_sort': 41,
#       'total': 96,
#       'league_id': 42482,
#       'rank_count': 2352,
#       'entry_percentile_rank': 5}],
#     'entry_rank': 65,
#     'entry_last_rank': 56},
#    {'id': 304012,
#     'name': 'FPL Manager India Open 2025/26',
#     'short_name': None,
#     'created': '2025-07-24T08:23:06.018940Z',
#     'closed': False,
#     'rank': None,
#     'max_entries': None,
#     'league_type': 'x',
#     'scoring': 'c',
#     'admin_entry': 34645,
#     'start_event': 1,
#     'entry_can_leave': True,
#     'entry_can_admin': False,
#     'entry_can_invite': False,
#     'has_cup': True,
#     'cup_league': None,
#     'cup_qualified': None,
#     'rank_count': 18467,
#     'entry_percentile_rank': 5,
#     'active_phases': [{'phase': 1,
#       'rank': 813,
#       'last_rank': 678,
#       'rank_sort': 852,
#       'total': 117,
#       'league_id': 304012,
#       'rank_count': 18467,
#       'entry_percentile_rank': 5},
#      {'phase': 2,
#       'rank': 470,
#       'last_rank': 678,
#       'rank_sort': 494,
#       'total': 96,
#       'league_id': 304012,
#       'rank_count': 18456,
#       'entry_percentile_rank': 5}],
#     'entry_rank': 813,
#     'entry_last_rank': 678},
#    {'id': 737774,
#     'name': 'Azim Premier League',
#     'short_name': None,
#     'created': '2025-08-03T10:46:42.815908Z',
#     'closed': False,
#     'rank': None,
#     'max_entries': None,
#     'league_type': 'x',
#     'scoring': 'c',
#     'admin_entry': 881701,
#     'start_event': 1,
#     'entry_can_leave': True,
#     'entry_can_admin': False,
#     'entry_can_invite': False,
#     'has_cup': True,
#     'cup_league': None,
#     'cup_qualified': None,
#     'rank_count': 55,
#     'entry_percentile_rank': 10,
#     'active_phases': [{'phase': 1,
#       'rank': 3,
#       'last_rank': 3,
#       'rank_sort': 3,
#       'total': 117,
#       'league_id': 737774,
#       'rank_count': 55,
#       'entry_percentile_rank': 10},
#      {'phase': 2,
#       'rank': 4,
#       'last_rank': 3,
#       'rank_sort': 4,
#       'total': 96,
#       'league_id': 737774,
#       'rank_count': 55,
#       'entry_percentile_rank': 10}],
#     'entry_rank': 3,
#     'entry_last_rank': 3},
#    {'id': 1144229,
#     'name': 'Rishi Valley Premier League',
#     'short_name': None,
#     'created': '2025-08-10T14:26:43.390080Z',
#     'closed': False,
#     'rank': None,
#     'max_entries': None,
#     'league_type': 'x',
#     'scoring': 'c',
#     'admin_entry': 5252797,
#     'start_event': 1,
#     'entry_can_leave': False,
#     'entry_can_admin': True,
#     'entry_can_invite': True,
#     'has_cup': True,
#     'cup_league': None,
#     'cup_qualified': None,
#     'rank_count': 19,
#     'entry_percentile_rank': 10,
#     'active_phases': [{'phase': 1,
#       'rank': 1,
#       'last_rank': 1,
#       'rank_sort': 1,
#       'total': 117,
#       'league_id': 1144229,
#       'rank_count': 19,
#       'entry_percentile_rank': 10},
#      {'phase': 2,
#       'rank': 1,
#       'last_rank': 1,
#       'rank_sort': 1,
#       'total': 96,
#       'league_id': 1144229,
#       'rank_count': 19,
#       'entry_percentile_rank': 10}],
#     'entry_rank': 1,
#     'entry_last_rank': 1},
#    {'id': 1144235,
#     'name': 'ISC 20',
#     'short_name': None,
#     'created': '2025-08-10T14:26:44.998982Z',
#     'closed': False,
#     'rank': None,
#     'max_entries': None,
#     'league_type': 'x',
#     'scoring': 'c',
#     'admin_entry': 5252797,
#     'start_event': 1,
#     'entry_can_leave': False,
#     'entry_can_admin': True,
#     'entry_can_invite': True,
#     'has_cup': True,
#     'cup_league': None,
#     'cup_qualified': None,
#     'rank_count': 5,
#     'entry_percentile_rank': 20,
#     'active_phases': [{'phase': 1,
#       'rank': 1,
#       'last_rank': 1,
#       'rank_sort': 1,
#       'total': 117,
#       'league_id': 1144235,
#       'rank_count': 5,
#       'entry_percentile_rank': 20},
#      {'phase': 2,
#       'rank': 1,
#       'last_rank': 1,
#       'rank_sort': 1,
#       'total': 96,
#       'league_id': 1144235,
#       'rank_count': 5,
#       'entry_percentile_rank': 20}],
#     'entry_rank': 1,
#     'entry_last_rank': 1}],
#   'h2h': [],
#   'cup': {'matches': [],
#    'status': {'qualification_event': None,
#     'qualification_numbers': None,
#     'qualification_rank': None,
#     'qualification_state': None},
#    'cup_league': None},
#   'cup_matches': []},
#  'name': 'Dharamshala Dhamakas',
#  'name_change_blocked': False,
#  'entered_events': [1, 2],
#  'kit': None,
#  'last_deadline_bank': 0,
#  'last_deadline_value': 1000,
#  'last_deadline_total_transfers': 1,
#  'club_badge_src': None}

# %%
data['player_first_name']
# Out:
# 'Arnav'

# %%
data['player_last_name']
# Out:
# 'Bhatia'

# %%
data['name']
# Out:
# 'Dharamshala Dhamakas'

# %%
data['summary_overall_points']
# Out:
# 117

# %%
data['summary_overall_rank']
# Out:
# 375361

# %%
for league in data['leagues']['classic']:
    if league['id'] == 314:
        overall = league
        print(league)
# Out:
# {'id': 314, 'name': 'Overall', 'short_name': 'overall', 'created': '2025-07-20T23:14:33.933835Z', 'closed': False, 'rank': None, 'max_entries': None, 'league_type': 's', 'scoring': 'c', 'admin_entry': None, 'start_event': 1, 'entry_can_leave': False, 'entry_can_admin': False, 'entry_can_invite': False, 'has_cup': True, 'cup_league': None, 'cup_qualified': None, 'rank_count': 10755611, 'entry_percentile_rank': 5, 'active_phases': [{'phase': 1, 'rank': 375361, 'last_rank': 288561, 'rank_sort': 386558, 'total': 117, 'league_id': 314, 'rank_count': 10755611, 'entry_percentile_rank': 5}, {'phase': 2, 'rank': 221120, 'last_rank': 288561, 'rank_sort': 229897, 'total': 96, 'league_id': 314, 'rank_count': 10757708, 'entry_percentile_rank': 5}], 'entry_rank': 375361, 'entry_last_rank': 288561}

# %%
overall
# Out:
# {'id': 314,
#  'name': 'Overall',
#  'short_name': 'overall',
#  'created': '2025-07-20T23:14:33.933835Z',
#  'closed': False,
#  'rank': None,
#  'max_entries': None,
#  'league_type': 's',
#  'scoring': 'c',
#  'admin_entry': None,
#  'start_event': 1,
#  'entry_can_leave': False,
#  'entry_can_admin': False,
#  'entry_can_invite': False,
#  'has_cup': True,
#  'cup_league': None,
#  'cup_qualified': None,
#  'rank_count': 10755611,
#  'entry_percentile_rank': 5,
#  'active_phases': [{'phase': 1,
#    'rank': 375361,
#    'last_rank': 288561,
#    'rank_sort': 386558,
#    'total': 117,
#    'league_id': 314,
#    'rank_count': 10755611,
#    'entry_percentile_rank': 5},
#   {'phase': 2,
#    'rank': 221120,
#    'last_rank': 288561,
#    'rank_sort': 229897,
#    'total': 96,
#    'league_id': 314,
#    'rank_count': 10757708,
#    'entry_percentile_rank': 5}],
#  'entry_rank': 375361,
#  'entry_last_rank': 288561}

# %%
MANAGER_HISTORY_URL = urljoin(f"{BASE_URL}/", f"{manager_id}/history")

# %%
history_response = requests.get(MANAGER_HISTORY_URL)

# %%
data2 = history_response.json()

# %%
data2['current']
# Out:
# [{'event': 1,
#   'points': 78,
#   'total_points': 78,
#   'rank': 288561,
#   'rank_sort': 316417,
#   'overall_rank': 288561,
#   'percentile_rank': 5,
#   'bank': 5,
#   'value': 1000,
#   'event_transfers': 0,
#   'event_transfers_cost': 0,
#   'points_on_bench': 3},
#  {'event': 2,
#   'points': 39,
#   'total_points': 117,
#   'rank': 2932372,
#   'rank_sort': 2979540,
#   'overall_rank': 375361,
#   'percentile_rank': 30,
#   'bank': 0,
#   'value': 1000,
#   'event_transfers': 1,
#   'event_transfers_cost': 0,
#   'points_on_bench': 13}]

# %%
import requests
session = requests.session()

# %%
url = 'https://users.premierleague.com/accounts/login/'
payload = {
 'password': 'F00tb@ll',
 'login': 'arnav.zomuana@gmail.com',
 'redirect_uri': 'https://fantasy.premierleague.com/a/login',
 'app': 'plfpl-web'
}
session.post(url, data=payload)
# Out:
# <Response [200]>

# %%
response = session.get('https://fantasy.premierleague.com/drf/my-team/5252797')

# %%
response.text
# Out:
# '<!DOCTYPE html>\n\n<html lang="en">\n    <head>\n        <!-- OneTrust Cookies Consent Notice start for premierleague.com -->\n        <script\n            charset="UTF-8"\n            data-domain-script="cdf436a9-4615-4772-a4b4-7660a91cc3a2"\n            src="https://cdn-ukwest.onetrust.com/scripttemplates/otSDKStub.js"\n            type="text/javascript"\n        ></script>\n        <script\n            defer=""\n            src="https://cc-embed.adobe.com/sdk/v4/CCEverywhere.js"\n        ></script>\n        <script async="" src="https://assets.adobedtm.com/e7ad550d4f82/693c01019a2b/launch-a4f579b5dcc4.min.js"></script>\n        <script id="ism-environment-paths">\n            if (!window.PULSE) {\n                window.PULSE = {};\n            }\n            window.PULSE.envPaths = {\n                label: "production",\n                domain: [\n                    "web25.premierleague.pulselive.com",\n                    "www.premierleague.com",\n                ],\n                cdn: "//www.premierleague.com/resources/v1.27.27/",\n                api: "//api.premierleague.com",\n                preferences:\n                    "https://api.premierleague.com/preferences/user/preferences",\n                copilotApi:\n                    "https://ai.premierleaguedigital.com/api/companion/v1/prompt/",\n                contentPersonalisationApi:\n                    "https://api.premierleague.com/personalisation",\n                firebase: {\n                    apiKey: "AIzaSyA-IEfY0MbeRPZlQkaxq-tytyzM7buoHYs",\n                    authDomain: "premier-league-app-v2-prod.firebaseapp.com",\n                    projectId: "premier-league-app-v2-prod",\n                    storageBucket:\n                        "premier-league-app-v2-prod.firebasestorage.app",\n                    messagingSenderId: "275434933608",\n                    appId: "1:275434933608:web:965f404a62d6a953b21add",\n                    measurementId: "G-X3CFNBHB32",\n                },\n            };\n        </script>\n        <script\n            charset="UTF-8"\n            id="translations-script"\n            src="//translations.premier-league-prod.pulselive.com/premierleague/en.js"\n        ></script>\n        <script type="text/javascript">\n            function OptanonWrapper() {}\n        </script>\n        <!-- OneTrust Cookies Consent Notice end for premierleague.com -->\n        <meta charset="utf-8" />\n        <meta content="ie=edge" http-equiv="x-ua-compatible" />\n        <meta content="width=device-width, initial-scale=1" name="viewport" />\n        <!-- title and description -->\n        <title>\n            Fantasy Premier League, Official Fantasy Football Game of the\n            Premier League\n        </title>\n        <meta\n            content="Official Fantasy Premier League 2025/26. Free to play fantasy football game, set up your fantasy football team at the Official Premier League site."\n            data-react-helmet="true"\n            name="description"\n        />\n        <!-- favicon related -->\n        <link\n            href="/img/favicons/apple-touch-icon.png"\n            rel="apple-touch-icon"\n            sizes="180x180"\n        />\n        <link\n            href="/img/favicons/favicon-32x32.png"\n            rel="icon"\n            sizes="32x32"\n            type="image/png"\n        />\n        <link\n            href="/img/favicons/favicon-16x16.png"\n            rel="icon"\n            sizes="16x16"\n            type="image/png"\n        />\n        <link href="/img/favicons/manifest.json" rel="manifest" />\n        <link\n            color="#5bbad5"\n            href="/img/favicons/safari-pinned-tab.svg"\n            rel="mask-icon"\n        />\n        <link href="/img/favicons/favicon.ico" rel="shortcut icon" />\n        <meta\n            content="/favicons/browserconfig.xml"\n            name="msapplication-config"\n        />\n        <meta content="#ffffff" name="theme-color" />\n        <!-- ...

# %%
import requests
import json

# --- YOUR FPL DETAILS ---
FPL_EMAIL = "arnav.zomuana@gmail.com"
FPL_PASSWORD = "F00tb@ll"
TEAM_ID = "5252797" # This is the number in the URL when you view your points

# --- URLS ---
LOGIN_URL = "https://users.premierleague.com/accounts/login/"
FPL_HOME_URL = "https://fantasy.premierleague.com/"
TEAM_URL = f"https://fantasy.premierleague.com/api/my-team/{TEAM_ID}/"

# 1. Start a session
session = requests.Session()

# 2. GET the FPL home page to get the required cookies (like csrftoken)
# A 'User-Agent' header is good practice to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
}
session.get(FPL_HOME_URL, headers=headers)

# 3. Get the csrf token from the session cookies
try:
    csrftoken = session.cookies['csrftoken']
except KeyError:
    print("❌ CSRF token not found. The website structure might have changed.")
    exit()

# 4. Prepare the login payload and headers for the POST request
payload = {
    'password': FPL_PASSWORD,
    'login': FPL_EMAIL,
    'redirect_uri': 'https://fantasy.premierleague.com/',
    'app': 'plfpl-web'
}

# The CSRF token needs to be in the headers for the POST request
post_headers = {
    **headers, # Use the same User-Agent
    'Referer': LOGIN_URL, # Important to show where the request is coming from
    "Content-Type": "application/x-www-form-urlencoded",
}

# 5. POST to the login URL to authenticate
response_post = session.post(LOGIN_URL, data=payload, headers=post_headers)

# A successful login often results in a 200 OK or a redirect.
# We can check if the 'pl_profile' cookie is set, which indicates a successful login.
if 'pl_profile' in session.cookies:
    print("✅ Login successful!")
else:
    print("❌ Login failed. Please check your credentials and the website's login process.")
    # You can print response_post.text here to see the HTML error page
    exit()

# 6. Now, get the protected team data
response_get = session.get(TEAM_URL, headers=headers)

# 7. Check the response and parse the JSON
if response_get.status_code == 200:
    print("✅ Successfully fetched team data.")
    try:
        team_data = response_get.json()
        # Pretty-print the JSON data
        print(json.dumps(team_data, indent=2))
    except json.JSONDecodeError:
        print("❌ Failed to decode JSON. The response was:")
        print(response_get.text)
else:
    print(f"❌ Failed to fetch team data. Status code: {response_get.status_code}")
    print("Response text:", response_get.text)
# Out:
# ❌ CSRF token not found. The website structure might have changed.
# ❌ Login failed. Please check your credentials and the website's login process.
# ❌ Failed to fetch team data. Status code: 403
# Response text: {"detail":"Authentication credentials were not provided."}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import requests
import json

# %%
session = requests.session()

headers={"User-Agent": "Dalvik/2.1.0 (Linux; U; Android 5.1; PRO 5 Build/LMY47D)", 'accept-language': 'en'}

data = { "login": "arnav.zomuana@gmail.com", "password": "F00tb@ll", "app": "plfpl-web", "redirect_uri": "https://fantasy.premierleague.com/a/login" }

url = "https://users.premierleague.com/accounts/login/"

res = session.post(url, data = data, headers = headers)

team_url = "https://fantasy.premierleague.com/api/my-team/5252797/"

res = session.get(team_url)

team = json.loads(res.content)

# %%
import base64
import hashlib
import os
import re
import secrets
import uuid
import json

from curl_cffi import requests
from dotenv import load_dotenv

load_dotenv()

CLIENT_ID = "bfcbaf69-aade-4c1b-8f00-c1cb8a193030"
URLS = {
    "auth": "https://account.premierleague.com/as/authorize",
    "start": "https://account.premierleague.com/davinci/policy/262ce4b01d19dd9d385d26bddb4297b6/start",
    "login": "https://account.premierleague.com/davinci/connections/{}/capabilities/customHTMLTemplate",
    "resume": "https://account.premierleague.com/as/resume",
    "token": "https://account.premierleague.com/as/token",
    "me": "https://fantasy.premierleague.com/api/me/",
}
STANDARD_CONNECTION_ID = "0d8c928e4970386733ce110b9dda8412"


def generate_code_verifier():
    return secrets.token_urlsafe(64)[:128]


def generate_code_challenge(verifier):
    digest = hashlib.sha256(verifier.encode()).digest()
    return base64.urlsafe_b64encode(digest).decode().rstrip("=")


code_verifier = generate_code_verifier()  # code_verifier for PKCE
code_challenge = generate_code_challenge(code_verifier)  # code_challenge from the code_verifier
initial_state = uuid.uuid4().hex  # random initial state for the OAuth flow

session = requests.Session(impersonate="chrome124")

# Step 1: Request authorization page
params = {
    "client_id": "bfcbaf69-aade-4c1b-8f00-c1cb8a193030",
    "redirect_uri": "https://fantasy.premierleague.com/",
    "response_type": "code",
    "scope": "openid profile email offline_access",
    "state": initial_state,
    "code_challenge": code_challenge,
    "code_challenge_method": "S256",
}
auth_response = session.get(URLS["auth"], params=params)
login_html = auth_response.text

access_token = re.search(r'"accessToken":"([^"]+)"', login_html).group(1)
# need to read state here for when we resume the OAuth flow later on
new_state = re.search(r'<input[^>]+name="state"[^>]+value="([^"]+)"', login_html).group(1)


# Step 2: Use accessToken to get interaction id and token
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json",
}
response = session.post(URLS["start"], headers=headers).json()
interaction_id = response["interactionId"]
interaction_token = response["interactionToken"]

# Step 3: log in with interaction tokens (requires 3 post requests)
response = session.post(
    URLS["login"].format(STANDARD_CONNECTION_ID),
    headers={
        "interactionId": interaction_id,
        "interactionToken": interaction_token,
    },
    json={
        "id": response["id"],
        "eventName": "continue",
        "parameters": {"eventType": "polling"},
        "pollProps": {"status": "continue", "delayInMs": 10, "retriesAllowed": 1, "pollChallengeStatus": False},
    },
)

response = session.post(
    URLS["login"].format(STANDARD_CONNECTION_ID),
    headers={
        "interactionId": interaction_id,
        "interactionToken": interaction_token,
    },
    json={
        "id": response.json()["id"],
        "nextEvent": {
            "constructType": "skEvent",
            "eventName": "continue",
            "params": [],
            "eventType": "post",
            "postProcess": {},
        },
        "parameters": {
            "buttonType": "form-submit",
            "buttonValue": "SIGNON",
            "username": os.getenv("EMAIL"),
            "password": os.getenv("PASSWORD"),
        },
        "eventName": "continue",
    },
).json()

response = session.post(
    URLS["login"].format(response["connectionId"]),  # need to use new connectionId from prev response
    headers=headers,
    json={
        "id": response["id"],
        "nextEvent": {
            "constructType": "skEvent",
            "eventName": "continue",
            "params": [],
            "eventType": "post",
            "postProcess": {},
        },
        "parameters": {
            "buttonType": "form-submit",
            "buttonValue": "SIGNON",
        },
        "eventName": "continue",
    },
)

# Step 4: Resume the login using the dv_response and handle redirect
response = session.post(
    URLS["resume"],
    data={
        "dvResponse": response.json()["dvResponse"],
        "state": new_state,
    },
    allow_redirects=False,
)

location = response.headers["Location"]
auth_code = re.search(r"[?&]code=([^&]+)", location).group(1)

# Step 5: Exchange auth code for access token
response = session.post(
    URLS["token"],
    data={
        "grant_type": "authorization_code",
        "redirect_uri": "https://fantasy.premierleague.com/",
        "code": auth_code,  # from the parsed redirect URL
        "code_verifier": code_verifier,  # the original code_verifier generated at the start
        "client_id": "bfcbaf69-aade-4c1b-8f00-c1cb8a193030",
    },
)

access_token = response.json()["access_token"]
refresh_token = response.json()["refresh_token"]

response = session.get(URLS["me"], headers={"X-API-Authorization": f"Bearer {access_token}"})

# print(response.json())

# print("\n--- Making a new request for specific team data ---")

# # 1. Define the headers, passing your token as a "Bearer" token.
# api_headers = {
#     "Authorization": f"Bearer {access_token}"
# }

# # 2. Define the URL you want to access
# team_id = "5252797"  # This is your team ID
# team_url = f"https://fantasy.premierleague.com/api/my-team/{team_id}/"

# # 3. Use your existing session to make the GET request with the headers
# my_team_response = session.get(team_url, headers=api_headers)

# # 4. Check the response and print the data
# if my_team_response.status_code == 200:
#     print(f"✅ Successfully fetched data for team ID {team_id}:")
#     print(json.dumps(my_team_response.json(), indent=2))
# else:
#     print(f"❌ Failed to fetch team data. Status code: {my_team_response.status_code}")
#     print("Response:", my_team_response.text)

url = "https://account.premierleague.com/as/token"
data = {
    "grant_type": "refresh_token",
    "refresh_token": refresh_token,
    "client_id": "bfcbaf69-aade-4c1b-8f00-c1cb8a193030",
}
headers = {"Content-Type": "application/x-www-form-urlencoded"}

response = requests.post(url, data=data, headers=headers)
tokens = response.json()
print(tokens)
# Out:
# {'detail': 'Authentication credentials were not provided.'}
